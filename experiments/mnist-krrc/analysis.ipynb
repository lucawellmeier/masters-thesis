# %%
import os
import numpy as np
from matplotlib import pyplot as plt

from dep_cache import *
from dep_declarations import *

# %%
Ntr = 6000
Nte = 2000
alphas100 = [0, 1, 2, 4, 8, 10, 16, 32, 64, 100, 128]
alphas = [a / 100 for a in alphas100]

# %%
pairs = []
for i in range(0,10):
    for j in range(i+1,10):
        pairs.append((i,j))

# %%
cache = ParallelDependencyCache(n_threads = 4)

for pair in pairs:
    i = pair[0]
    j = pair[1]
    cache.request(CovSpec(Ntr,Nte,i,j))
    cache.request(KernelSpec(Ntr,Nte,i,j))
    for alpha100 in alphas100:
        cache.request(Errors(Ntr,Nte,i,j,alpha100))

cache.fetch_all()
# Out:
# already cached: ./cache/covspec_400_200_0_1.npz
# already cached: ./cache/kernelspec_400_200_0_1.npz
# already cached: ./cache/errors_400_200_0_1_50.npy
# already cached: ./cache/covspec_400_200_0_2.npz
# already cached: ./cache/kernelspec_400_200_0_2.npz
# already cached: ./cache/errors_400_200_0_2_50.npy
# already cached: ./cache/covspec_400_200_0_3.npz
# already cached: ./cache/kernelspec_400_200_0_3.npz
# already cached: ./cache/errors_400_200_0_3_50.npy
# already cached: ./cache/covspec_400_200_0_4.npz
# already cached: ./cache/kernelspec_400_200_0_4.npz
# already cached: ./cache/errors_400_200_0_4_50.npy
# already cached: ./cache/covspec_400_200_0_5.npz
# already cached: ./cache/kernelspec_400_200_0_5.npz
# already cached: ./cache/errors_400_200_0_5_50.npy
# already cached: ./cache/covspec_400_200_0_6.npz
# already cached: ./cache/kernelspec_400_200_0_6.npz
# already cached: ./cache/errors_400_200_0_6_50.npy
# already cached: ./cache/covspec_400_200_0_7.npz
# already cached: ./cache/kernelspec_400_200_0_7.npz
# already cached: ./cache/errors_400_200_0_7_50.npy
# already cached: ./cache/covspec_400_200_0_8.npz
# already cached: ./cache/kernelspec_400_200_0_8.npz
# already cached: ./cache/errors_400_200_0_8_50.npy
# already cached: ./cache/covspec_400_200_0_9.npz
# already cached: ./cache/kernelspec_400_200_0_9.npz
# already cached: ./cache/errors_400_200_0_9_50.npy
# already cached: ./cache/covspec_400_200_1_2.npz
# already cached: ./cache/kernelspec_400_200_1_2.npz
# already cached: ./cache/covspec_400_200_1_3.npz
# already cached: ./cache/kernelspec_400_200_1_3.npz
# already cached: ./cache/errors_400_200_1_3_50.npy
# already cached: ./cache/covspec_400_200_1_4.npz
# already cached: ./cache/kernelspec_400_200_1_4.npz
# already cached: ./cache/errors_400_200_1_4_50.npy
# already cached: ./cache/covspec_400_200_1_5.npz
# already cached: ./cache/kernelspec_400_200_1_5.npz
# already cached: ./cache/errors_400_200_1_5_50.npy
# already cached: ./cache/covspec_400_200_1_6.npz
# already cached: ./cache/kernelspec_400_200_1_6.npz
# already cached: ./cache/errors_400_200_1_6_50.npy
# already cached: ./cache/covspec_400_200_1_7.npz
# already cached: ./cache/kernelspec_400_200_1_7.npz
# already cached: ./cache/errors_400_200_1_7_50.npy
# already cached: ./cache/covspec_400_200_1_8.npz
# already cached: ./cache/kernelspec_400_200_1_8.npz
# already cached: ./cache/errors_400_200_1_8_50.npy
# already cached: ./cache/covspec_400_200_1_9.npz
# already cached: ./cache/kernelspec_400_200_1_9.npz
# already cached: ./cache/errors_400_200_1_9_50.npy
# already cached: ./cache/covspec_400_200_2_3.npz
# already cached: ./cache/kernelspec_400_200_2_3.npz
# already cached: ./cache/errors_400_200_2_3_50.npy
# already cached: ./cache/covspec_400_200_2_4.npz
# already cached: ./cache/kernelspec_400_200_2_4.npz
# already cached: ./cache/errors_400_200_2_4_50.npy
# already cached: ./cache/covspec_400_200_2_5.npz
# already cached: ./cache/kernelspec_400_200_2_5.npz
# already cached: ./cache/errors_400_200_2_5_50.npy
# already cached: ./cache/covspec_400_200_2_6.npz
# already cached: ./cache/kernelspec_400_200_2_6.npz
# already cached: ./cache/errors_400_200_2_6_50.npy
# already cached: ./cache/covspec_400_200_2_7.npz
# already cached: ./cache/kernelspec_400_200_2_7.npz
# already cached: ./cache/errors_400_200_2_7_50.npy
# already cached: ./cache/covspec_400_200_2_8.npz
# already cached: ./cache/kernelspec_400_200_2_8.npz
# already cached: ./cache/errors_400_200_2_8_50.npy
# already cached: ./cache/covspec_400_200_2_9.npz
# already cached: ./cache/kernelspec_400_200_2_9.npz
# already cached: ./cache/errors_400_200_2_9_50.npy
# already cached: ./cache/covspec_400_200_3_4.npz
# already cached: ./cache/kernelspec_400_200_3_4.npz
# already cached: ./cache/errors_400_200_3_4_50.npy
# already cached: ./cache/covspec_400_200_3_5.npz
# already cached: ./cache/kernelspec_400_200_3_5.npz
# already cached: ./cache/errors_400_200_3_5_50.npy
# already cached: ./cache/covspec_400_200_3_6.npz
# already cached: ./cache/kernelspec_400_200_3_6.npz
# already cached: ./cache/errors_400_200_3_6_50.npy
# already cached: ./cache/covspec_400_200_3_7.npz
# already cached: ./cache/kernelspec_400_200_3_7.npz
# already cached: ./cache/errors_400_200_3_7_50.npy
# already cached: ./cache/covspec_400_200_3_8.npz
# already cached: ./cache/kernelspec_400_200_3_8.npz
# already cached: ./cache/errors_400_200_3_8_50.npy
# already cached: ./cache/covspec_400_200_3_9.npz
# already cached: ./cache/errors_400_200_3_9_50.npy
# already cached: ./cache/covspec_400_200_4_5.npz
# already cached: ./cache/kernelspec_400_200_4_5.npz
# already cached: ./cache/errors_400_200_4_5_50.npy
# already cached: ./cache/covspec_400_200_4_6.npz
# already cached: ./cache/kernelspec_400_200_4_6.npz
# already cached: ./cache/errors_400_200_4_6_50.npy
# already cached: ./cache/covspec_400_200_4_7.npz
# already cached: ./cache/kernelspec_400_200_4_7.npz
# already cached: ./cache/errors_400_200_4_7_50.npy
# already cached: ./cache/covspec_400_200_4_8.npz
# already cached: ./cache/kernelspec_400_200_4_8.npz
# already cached: ./cache/errors_400_200_4_8_50.npy
# already cached: ./cache/kernelspec_400_200_4_9.npz
# already cached: ./cache/errors_400_200_4_9_50.npy
# already cached: ./cache/covspec_400_200_5_6.npz
# already cached: ./cache/errors_400_200_5_6_50.npy
# already cached: ./cache/covspec_400_200_5_7.npz
# already cached: ./cache/kernelspec_400_200_5_7.npz
# already cached: ./cache/errors_400_200_5_7_50.npy
# already cached: ./cache/covspec_400_200_5_8.npz
# already cached: ./cache/kernelspec_400_200_5_8.npz
# already cached: ./cache/errors_400_200_5_8_50.npy
# already cached: ./cache/covspec_400_200_5_9.npz
# already cached: ./cache/kernelspec_400_200_5_9.npz
# already cached: ./cache/errors_400_200_5_9_50.npy
# already cached: ./cache/covspec_400_200_6_7.npz
# already cached: ./cache/kernelspec_400_200_6_7.npz
# already cached: ./cache/errors_400_200_6_7_50.npy
# already cached: ./cache/covspec_400_200_6_8.npz
# already cached: ./cache/kernelspec_400_200_6_8.npz
# already cached: ./cache/errors_400_200_6_8_50.npy
# already cached: ./cache/covspec_400_200_6_9.npz
# already cached: ./cache/kernelspec_400_200_6_9.npz
# already cached: ./cache/errors_400_200_6_9_50.npy
# already cached: ./cache/covspec_400_200_7_8.npz
# already cached: ./cache/kernelspec_400_200_7_8.npz
# already cached: ./cache/errors_400_200_7_8_50.npy
# already cached: ./cache/covspec_400_200_7_9.npz
# already cached: ./cache/kernelspec_400_200_7_9.npz
# already cached: ./cache/errors_400_200_7_9_50.npy
# already cached: ./cache/covspec_400_200_8_9.npz
# already cached: ./cache/kernelspec_400_200_8_9.npz
# already cached: ./cache/errors_400_200_8_9_50.npy
# [1] starting: ./cache/mnist.npz
# [1] finished: ./cache/mnist.npz (0.00 seconds)
# [1] starting: ./cache/digit_1.npz
# [2] starting: ./cache/digit_2.npz
# [3] starting: ./cache/digit_3.npz
# [4] starting: ./cache/digit_9.npz
# [1] finished: ./cache/digit_1.npz (3.37 seconds)
# [1] starting: ./cache/digit_4.npz
# [3] finished: ./cache/digit_3.npz (3.54 seconds)
# [3] starting: ./cache/digit_5.npz
# [4] finished: ./cache/digit_9.npz (3.60 seconds)
# [4] starting: ./cache/traintestsplit_400_200_3_9.npz
# [2] finished: ./cache/digit_2.npz (3.64 seconds)
# [2] starting: ./cache/traintestsplit_400_200_1_2.npz
# [4] finished: ./cache/traintestsplit_400_200_3_9.npz (0.67 seconds)
# [4] delete ./cache/digit_3.npz
# [4] starting: ./cache/kernels_400_200_3_9.npz
# [2] finished: ./cache/traintestsplit_400_200_1_2.npz (0.68 seconds)
# [2] delete ./cache/digit_1.npz
# [2] delete ./cache/digit_2.npz
# [2] starting: ./cache/kernels_400_200_1_2.npz
# [4] finished: ./cache/kernels_400_200_3_9.npz (0.37 seconds)
# [4] delete ./cache/traintestsplit_400_200_3_9.npz
# [4] starting: ./cache/kernelspec_400_200_3_9.npz
# [2] finished: ./cache/kernels_400_200_1_2.npz (0.39 seconds)
# [2] starting: ./cache/errors_400_200_1_2_50.npy
# [2] finished: ./cache/errors_400_200_1_2_50.npy (0.05 seconds)
# [2] delete ./cache/traintestsplit_400_200_1_2.npz
# [2] delete ./cache/kernels_400_200_1_2.npz
# [2] starting: ./cache/digit_6.npz
# [4] finished: ./cache/kernelspec_400_200_3_9.npz (0.69 seconds)
# [4] delete ./cache/kernels_400_200_3_9.npz
# [1] finished: ./cache/digit_4.npz (3.06 seconds)
# [1] starting: ./cache/traintestsplit_400_200_4_9.npz
# [3] finished: ./cache/digit_5.npz (3.12 seconds)
# [1] finished: ./cache/traintestsplit_400_200_4_9.npz (0.39 seconds)
# [1] delete ./cache/digit_4.npz
# [1] delete ./cache/digit_9.npz
# [1] starting: ./cache/covspec_400_200_4_9.npz
# [1] finished: ./cache/covspec_400_200_4_9.npz (0.08 seconds)
# [1] delete ./cache/traintestsplit_400_200_4_9.npz
# [2] finished: ./cache/digit_6.npz (2.48 seconds)
# [2] starting: ./cache/traintestsplit_400_200_5_6.npz
# [2] finished: ./cache/traintestsplit_400_200_5_6.npz (0.35 seconds)
# [2] delete ./cache/digit_5.npz
# [2] delete ./cache/digit_6.npz
# [2] starting: ./cache/kernels_400_200_5_6.npz
# [2] finished: ./cache/kernels_400_200_5_6.npz (0.25 seconds)
# [2] delete ./cache/traintestsplit_400_200_5_6.npz
# [2] starting: ./cache/kernelspec_400_200_5_6.npz
# [2] finished: ./cache/kernelspec_400_200_5_6.npz (0.37 seconds)
# [2] delete ./cache/kernels_400_200_5_6.npz
# TOTAL TIME: 8.24 seconds

# %%
errors = {}
for pair in pairs:
    errors[pair] = {'train': [], 'test': []}
    for alpha100 in alphas100:
        train,test = Errors(Ntr, Nte, pair[0], pair[1], alpha100).get()
        errors[pair]['train'].append(train)
        errors[pair]['test'].append(test)

# %%
print('Cases where no-regularization does not perform the best')
for pair in pairs:
    m = np.min(np.argmin(errors[pair]['test']))
    if m != 0:
        print('in', pair, 'the min is', m)
# Out:
# Cases where no-regularization does not perform the best

# %%
kernel_spec = {}
for pair in pairs:
    spec = KernelSpec(Ntr, Nte, pair[0], pair[1]).get()
    kernel_spec[pair] = np.flip(np.sort(np.abs(spec)))

# %%
cov_spec = {}
for pair in pairs:
    spec = CovSpec(Ntr, Nte, pair[0], pair[1]).get()
    cov_spec[pair] = np.flip(np.sort(np.abs(spec)))

# %%
subpairs_errors = [(2,5),(2,6),(2,7),(2,8),(2,9),
                   (3,5),(3,6),(3,7),(3,8),(3,9),
                   (4,5),(4,6),(4,7),(4,8),(4,9)]

# %%
for pair in subpairs_errors:
    plt.plot(alphas, errors[pair]['train'], label=str(pair))

plt.title('MNIST KRRC train errors')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=2)
plt.tight_layout()
plt.savefig('train_errors.png', dpi=96, facecolor='white', transparent=False)

# %%
for pair in subpairs_errors:
    plt.plot(alphas, errors[pair]['test'], label=str(pair))

plt.title('MNIST KRRC test errors')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=2)
plt.tight_layout()
plt.savefig('test_errors.png', dpi=96, facecolor='white', transparent=False)

# %%
subpairs_spectra = [(2,5),(2,9),(3,6),(3,8),(3,9),(4,7), (4,9)]
indices = list(range(1,101))

# %%
for pair in subpairs_spectra:
    plt.plot(indices, cov_spec[pair][:100], label=str(pair))

plt.title('MNIST covariance spectrum')
plt.xlabel('index')
plt.ylabel('log(eigenvalue)')
plt.yscale('log')
plt.legend(ncol=2)
plt.tight_layout()
plt.savefig('spectrum_covariance.png', dpi=96, facecolor='white', transparent=False)

# %%
for pair in subpairs_spectra:
    plt.plot(indices, kernel_spec[pair][:100], label=str(pair))

plt.title('MNIST kernel spectrum')
plt.xlabel('index')
plt.ylabel('log(eigenvalue)')
plt.yscale('log')
plt.legend(ncol=2)
plt.tight_layout()
plt.savefig('spectrum_kernel.png', dpi=96, facecolor='white', transparent=False)
